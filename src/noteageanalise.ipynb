# %% [markdown]
# ## Analise Qualitativa  X Quantitativa (Esporte x Idade)

# %%
import seaborn as sns
import pandas as pd
from data_cleaner import *

# %%
df = pd.read_csv("../data/athlete_events.csv")

# %%
print("Conferindo se possui todas as colunas necessárias")
cleaned_data= dataframe_cleaner(df)
print()
print("dataframe possui todas colunas necessárias")
print()
print("Conferindo os tipos de medahas para int")
cleaned_data = medals_to_int(cleaned_data)
print("Medalhas convertidas")
print()
print("tratando dados faltantes")
cleaned_data = predict_missing(cleaned_data)
print("Dados faltantes tratados")
print()
print("podemos começar")
# Out:
# Conferindo se possui todas as colunas necessária
#
# dataframe possui todas colunas necessárias
#
# Conferindo os tipos de medahas para int
# Medalhas convertidas
#
# tratando dados faltantes
# Dados faltantes tratados
#
# podemos começar

# %%
cleaned_data
# Out:
#             ID                      Name Sex  Age  Height  Weight  \
# 0            1                 A Dijiang   M   24     180      80
# 1            2                  A Lamusi   M   23     170      60
# 2            3       Gunnar Nielsen Aaby   M   24     178      73
# 3            4      Edgar Lindenau Aabye   M   34     182      96
# 4            5  Christine Jacoba Aaftink   F   21     185      82
# ...        ...                       ...  ..  ...     ...     ...
# 271111  135569                Andrzej ya   M   29     179      89
# 271112  135570                  Piotr ya   M   27     176      59
# 271113  135570                  Piotr ya   M   27     176      59
# 271114  135571        Tomasz Ireneusz ya   M   30     185      96
# 271115  135571        Tomasz Ireneusz ya   M   34     185      96
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 271111        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114          Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event  Medal
# 0          Basketball               Basketball Men's Basketball      0
# 1                Judo              Judo Men's Extra-Lightweight      0
# 2            Football                   Football Men's Football      0
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War      3
# 4       Speed Skating          Speed Skating Women's 500 metres      0
# ...               ...                                       ...    ...
# 271111           Luge                Luge Mixed (Men)'s Doubles      0
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual      0
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team      0
# 271114      Bobsleigh                      Bobsleigh Men's Four      0
# 271115      Bobsleigh                      Bobsleigh Men's Four      0
#
# [270521 rows x 15 columns]

# %% [markdown]
# Começando a análise

# %%
data_group_by_sport = cleaned_data.groupby('Sport').mean(numeric_only=True)
data_group_by_sport
# Out:
#                                      ID        Age      Height     Weight  \
# Sport
# Alpine Skiing              66487.294371  23.212482  173.786273  72.577868
# Archery                    71015.393316  27.958869  173.493573  70.509854
# Art Competitions           66682.060918  46.054358  174.998126  75.004998
# Athletics                  66880.006214  25.156561  176.627848  69.750000
# Badminton                  72112.463281  25.671242  173.923130  67.893617
# Baseball                   68054.561521  26.240492  182.620805  85.723714
# Basketball                 66967.785494  25.311287  191.451940  86.759700
# Beach Volleyball           69048.297872  29.122340  186.226950  79.163121
# Biathlon                   70200.979767  26.533006  174.167791  66.809933
# Bobsleigh                  68862.885219  29.107587  181.582080  89.458143
# Boxing                     66578.339507  23.051927  172.866711  65.182074
# Canoeing                   69580.021877  25.506887  178.610274  76.601199
# Cross Country Skiing       69507.345341  26.006132  173.683127  66.492500
# Curling                    73592.492441  31.412527  174.395248  72.604752
# Cycling                    67762.976241  24.725665  176.563035  70.544986
# Diving                     67293.426108  22.495778  167.205841  61.342013
# Equestrianism              66868.571721  34.378941  174.972573  68.529634
# Fencing                    66399.429716  28.561993  177.949790  72.504891
# Figure Skating             69754.657093  22.238903  168.228460  59.621410
# Football                   65371.418236  23.710304  176.170200  71.234248
# Freestyle Skiing           68039.012807  24.426894  171.048026  67.120598
# Golf                       69299.040486  29.412955  176.097166  74.615385
# Gymnastics                 70186.577414  22.814019  163.792414  57.953420
# Handball                   66879.347067  26.310232  183.467667  81.528786
# Hockey                     68197.023629  25.727524  173.990585  69.817427
# Ice Hockey                 71028.425671  25.832306  179.245649  81.346265
# Judo                       67646.257301  25.326230  174.295975  78.857143
# Lacrosse                   59381.000000  26.916667  174.000000  76.966667
# Luge                       72449.816092  24.626775  176.635565  77.273158
# Modern Pentathlon          66970.460346  26.376267  178.186047  70.704234
# Motorboating               77704.000000  33.875000  181.000000  77.000000
# Nordic Combined            67647.790923  24.340030  176.420387  66.927083
# Rhythmic Gymnastics        71801.252280  18.737082  167.875380  48.776596
# Rowing                     68872.892780  25.262577  184.820104  80.939028
# Rugby                      65776.135802  24.271605  176.037037  77.913580
# Rugby Sevens               67953.153846  26.046823  175.314381  78.939799
# Sailing                    65765.162770  30.319010  178.625418  76.629821
# Shooting                   67920.568484  33.462788  174.321716  75.379630
# Short Track Speed Skating  70178.235984  22.804433  170.112777  64.310300
# Skeleton                   68590.417085  29.844221  176.703518  75.045226
# Ski Jumping                69598.888380  23.345273  176.494794  65.044148
# Snowboarding               68818.767094  24.825855  173.090812  69.564103
# Softball                   74221.504184  26.299163  169.370293  67.512552
# Speed Skating              70934.587565  24.305897  174.781578  70.946909
# Swimming                   68430.589825  20.572753  178.849537  71.035266
# Synchronized Swimming      66979.830583  22.365237  168.457646  55.872387
# Table Tennis               70952.684399  26.462404  171.183120  64.871611
# Taekwondo                  64771.420792  24.056106  176.693069  67.991749
# Tennis                     70200.404612  25.880853  179.706150  71.977289
# Trampolining               66532.473684  25.138158  166.552632  59.368421
# Triathlon                  69223.224953  27.871456  173.633270  61.805293
# Tug-Of-War                 70270.747059  29.229412  182.070588  95.882353
# Volleyball                 70635.202996  25.185958  187.024971  78.948590
# Water Polo                 68645.384295  25.677327  185.430317  85.568123
# Weightlifting              69105.432563  25.528067  168.095250  78.773940
# Wrestling                  67972.349036  25.812133  172.520688  75.623427
#
#                                   Year     Medal
# Sport
# Alpine Skiing              1985.203534  0.097180
# Archery                    1987.533847  0.318338
# Art Competitions           1933.018432  0.091221
# Athletics                  1975.040182  0.206633
# Badminton                  2003.039121  0.226493
# Baseball                   2000.416107  0.751678
# Basketball                 1981.830688  0.478175
# Beach Volleyball           2006.212766  0.255319
# Biathlon                   1998.754139  0.166973
# Bobsleigh                  1981.806409  0.259320
# Boxing                     1976.415413  0.280966
# Canoeing                   1987.847026  0.377410
# Cross Country Skiing       1987.426256  0.169167
# Curling                    2003.261339  0.658747
# Cycling                    1974.303343  0.233539
# Diving                     1975.733990  0.300141
# Equestrianism              1974.556747  0.305013
# Fencing                    1962.465394  0.327340
# Figure Skating             1980.550044  0.337685
# Football                   1975.604151  0.461675
# Freestyle Skiing           2005.272145  0.217716
# Golf                       1958.056680  0.368421
# Gymnastics                 1969.674617  0.171640
# Handball                   1994.133697  0.577353
# Hockey                     1982.253646  0.565258
# Ice Hockey                 1983.096809  0.554931
# Judo                       1997.195475  0.251776
# Lacrosse                   1905.600000  2.200000
# Luge                       1990.389452  0.244760
# Modern Pentathlon          1974.203936  0.221825
# Motorboating               1908.000000  1.312500
# Nordic Combined            1985.141369  0.245536
# Rhythmic Gymnastics        2003.161094  0.401216
# Rowing                     1974.861350  0.554790
# Rugby                      1913.308642  2.314815
# Rugby Sevens               2016.000000  0.494983
# Sailing                    1976.682053  0.386729
# Shooting                   1965.897275  0.214797
# Short Track Speed Skating  2003.867014  0.370926
# Skeleton                   1999.718593  0.301508
# Ski Jumping                1985.729279  0.172845
# Snowboarding               2007.833333  0.192308
# Softball                   2001.991632  0.751046
# Speed Skating              1981.594869  0.207198
# Swimming                   1983.841862  0.268980
# Synchronized Swimming      2001.548955  0.477448
# Table Tennis               2002.142199  0.168798
# Taekwondo                  2008.343234  0.435644
# Tennis                     1976.989518  0.229909
# Trampolining               2008.421053  0.394737
# Triathlon                  2008.234405  0.113422
# Tug-Of-War                 1909.552941  1.435294
# Volleyball                 1992.202115  0.568449
# Water Polo                 1975.624545  0.547062
# Weightlifting              1980.595377  0.328423
# Wrestling                  1972.972044  0.354627

# %% [markdown]
# Adicionando os dados estatísticos ánalise qualitativa (esporte) X quantitativa (idade)

# %%
def estatisticas_idade_por_esporte(df: pd.DataFrame) -> dict:
    """
    Função que agrupa o DataFrame pela coluna 'Sport' e calcula mediana, 1º quartil (Q1) e 3º quartil (Q3)
    apenas para a coluna 'Age'.
    
    Args:
        df (pd.DataFrame): O DataFrame com os dados esportivos.
    
    Returns:
        dict: Um dicionário contendo as estatísticas da coluna 'Age' para cada esporte.
    """
    
    # Verifica se as colunas 'Sport' e 'Age' existem no DataFrame
    if 'Sport' not in df.columns or 'Age' not in df.columns:
        raise ValueError("As colunas 'Sport' e/ou 'Age' não estão presentes no DataFrame.")
    
    # Inicializando um dicionário para armazenar os resultados
    estatisticas = {}
    
    # Agrupando o DataFrame pela coluna 'Sport'
    grouped = df.groupby('Sport')

    # Iterando por cada grupo (esporte)
    for sport, group in grouped:
        estatisticas[sport] = {}
        
        # Selecionando a coluna 'Age'
        idade = group['Age']

        # Dados estatísticos da coluna 'Age' para aquele esporte 
        estatisticas[sport]['mediana'] = idade.median()
        estatisticas[sport]['1º quartil'] = idade.quantile(0.25)
        estatisticas[sport]['3º quartil'] = idade.quantile(0.75)
        estatisticas[sport]['minimo'] = idade.min()
        estatisticas[sport]['maximo'] = idade.max()
        estatisticas[sport]['media'] = idade.mean()
        estatisticas[sport]['desvio_padrao'] = idade.std()
        estatisticas[sport]['variancia'] = idade.var()
        
        #  Calculando os limites inferiores e superiores com base da idade
        interquartil = idade.quantile(0.75) - idade.quantile(0.25)
        limite_inferior = idade.quantile(0.25) - interquartil*1.5
        limite_superior = idade.quantile(0.75) + interquartil*1.5
        
        # Por serem variáveis discretas
        estatisticas[sport]['limite inferior'] = round(limite_inferior)
        estatisticas[sport]['limite superior'] = round(limite_superior) 
        
    
    return estatisticas

# %%
estatisticas = estatisticas_idade_por_esporte(cleaned_data)
estatisticas
# Out:
# {'Alpine Skiing': {'mediana': 23.0,
#   '1º quartil': 20.0,
#   '3º quartil': 25.0,
#   'minimo': 14,
#   'maximo': 55,
#   'media': 23.21248159474459,
#   'desvio_padrao': 3.9709152229971534,
#   'variancia': 15.768167708230532,
#   'limite inferior': 12.5,
#   'limite superior': 32.5},
#  'Archery': {'mediana': 26.0,
#   '1º quartil': 22.0,
#   '3º quartil': 32.0,
#   'minimo': 14,
#   'maximo': 71,
#   'media': 27.958868894601544,
#   'desvio_padrao': 8.730033281909629,
#   'variancia': 76.21348110324979,
#   'limite inferior': 7.0,
#   'limite superior': 47.0},
#  'Art Competitions': {'mediana': 46.0,
#   '1º quartil': 39.0,
#   '3º quartil': 53.0,
#   'minimo': 14,
#   'maximo': 97,
#   'media': 46.0543580131209,
#   'desvio_padrao': 11.590197120111313,
#   'variancia': 134.33266928303655,
#   'limite inferior': 18.0,
#   'limite superior': 74.0},
#  'Athletics': {'mediana': 25.0,
#   '1º quartil': 22.0,
#   '3º quartil': 28.0,
#   'minimo': 12,
#   'maximo': 52,
#   'media': 25.156560687655343,
#   'desvio_padrao': 4.334277764493852,
#   'variancia': 18.785963739785828,
#   'limite inferior': 13.0,
#   'limite superior': 37.0},
#  'Badminton': {'mediana': 25.0,
#   '1º quartil': 23.0,
#   '3º quartil': 28.0,
#   'minimo': 16,
#   'maximo': 44,
#   'media': 25.67124227865477,
#   'desvio_padrao': 3.907368800349866,
#   'variancia': 15.26753094194755,
#   'limite inferior': 15.5,
#   'limite superior': 35.5},
#  'Baseball': {'mediana': 26.0,
#   '1º quartil': 23.0,
#   '3º quartil': 29.0,
#   'minimo': 16,
#   'maximo': 44,
#   'media': 26.24049217002237,
#   'desvio_padrao': 4.559829246651374,
#   'variancia': 20.792042758617235,
#   'limite inferior': 14.0,
#   'limite superior': 38.0},
#  'Basketball': {'mediana': 25.0,
#   '1º quartil': 22.75,
#   '3º quartil': 28.0,
#   'minimo': 16,
#   'maximo': 40,
#   'media': 25.311287477954146,
#   'desvio_padrao': 3.801365218728462,
#   'variancia': 14.450377526158489,
#   'limite inferior': 14.875,
#   'limite superior': 35.875},
#  'Beach Volleyball': {'mediana': 29.0,
#   '1º quartil': 26.0,
#   '3º quartil': 32.0,
#   'minimo': 18,
#   'maximo': 41,
#   'media': 29.122340425531913,
#   'desvio_padrao': 4.2255583907206296,
#   'variancia': 17.855343713389516,
#   'limite inferior': 17.0,
#   'limite superior': 41.0},
#  'Biathlon': {'mediana': 26.0,
#   '1º quartil': 23.0,
#   '3º quartil': 29.0,
#   'minimo': 17,
#   'maximo': 45,
#   'media': 26.533006335581444,
#   'desvio_padrao': 4.288976902402067,
#   'variancia': 18.39532286933843,
#   'limite inferior': 14.0,
#   'limite superior': 38.0},
#  'Bobsleigh': {'mediana': 28.0,
#   '1º quartil': 25.0,
#   '3º quartil': 32.0,
#   'minimo': 15,
#   'maximo': 54,
#   'media': 29.10758665794637,
#   'desvio_padrao': 5.373264118277452,
#   'variancia': 28.87196728476796,
#   'limite inferior': 14.5,
#   'limite superior': 42.5},
#  'Boxing': {'mediana': 23.0,
#   '1º quartil': 21.0,
#   '3º quartil': 25.0,
#   'minimo': 15,
#   'maximo': 41,
#   'media': 23.051926575161236,
#   'desvio_padrao': 3.3507025015095158,
#   'variancia': 11.227207253622128,
#   'limite inferior': 15.0,
#   'limite superior': 31.0},
#  'Canoeing': {'mediana': 25.0,
#   '1º quartil': 22.0,
#   '3º quartil': 28.0,
#   'minimo': 15,
#   'maximo': 48,
#   'media': 25.506887052341597,
#   'desvio_padrao': 4.5303667870635245,
#   'variancia': 20.524223225328278,
#   'limite inferior': 13.0,
#   'limite superior': 37.0},
#  'Cross Country Skiing': {'mediana': 26.0,
#   '1º quartil': 23.0,
#   '3º quartil': 29.0,
#   'minimo': 15,
#   'maximo': 49,
#   'media': 26.006131610642726,
#   'desvio_padrao': 4.290375407553035,
#   'variancia': 18.407321137735874,
#   'limite inferior': 14.0,
#   'limite superior': 38.0},
#  'Curling': {'mediana': 30.0,
#   '1º quartil': 26.0,
#   '3º quartil': 36.0,
#   'minimo': 17,
#   'maximo': 58,
#   'media': 31.41252699784017,
#   'desvio_padrao': 7.259596923835642,
#   'variancia': 52.70174749656391,
#   'limite inferior': 11.0,
#   'limite superior': 51.0},
#  'Cycling': {'mediana': 24.0,
#   '1º quartil': 22.0,
#   '3º quartil': 27.0,
#   'minimo': 14,
#   'maximo': 49,
#   'media': 24.725665346717008,
#   'desvio_padrao': 4.291374157481697,
#   'variancia': 18.415892159501745,
#   'limite inferior': 14.5,
#   'limite superior': 34.5},
#  'Diving': {'mediana': 22.0,
#   '1º quartil': 19.0,
#   '3º quartil': 25.0,
#   'minimo': 12,
#   'maximo': 51,
#   'media': 22.495777621393383,
#   'desvio_padrao': 4.304432745920455,
#   'variancia': 18.528141264152314,
#   'limite inferior': 10.0,
#   'limite superior': 34.0},
#  'Equestrianism': {'mediana': 34.0,
#   '1º quartil': 28.0,
#   '3º quartil': 40.0,
#   'minimo': 16,
#   'maximo': 72,
#   'media': 34.378940731399744,
#   'desvio_padrao': 8.298743957143929,
#   'variancia': 68.86915126623286,
#   'limite inferior': 10.0,
#   'limite superior': 58.0},
#  'Fencing': {'mediana': 28.0,
#   '1º quartil': 24.0,
#   '3º quartil': 32.0,
#   'minimo': 14,
#   'maximo': 63,
#   'media': 28.561993479273404,
#   'desvio_padrao': 6.318030112575,
#   'variancia': 39.91750450340447,
#   'limite inferior': 12.0,
#   'limite superior': 44.0},
#  'Figure Skating': {'mediana': 22.0,
#   '1º quartil': 19.0,
#   '3º quartil': 25.0,
#   'minimo': 11,
#   'maximo': 52,
#   'media': 22.238903394255875,
#   'desvio_padrao': 4.965612794085894,
#   'variancia': 24.65731042078952,
#   'limite inferior': 10.0,
#   'limite superior': 34.0},
#  'Football': {'mediana': 23.0,
#   '1º quartil': 21.0,
#   '3º quartil': 26.0,
#   'minimo': 15,
#   'maximo': 40,
#   'media': 23.710303928836176,
#   'desvio_padrao': 3.4546703194595128,
#   'variancia': 11.93474701615449,
#   'limite inferior': 13.5,
#   'limite superior': 33.5},
#  'Freestyle Skiing': {'mediana': 24.0,
#   '1º quartil': 21.0,
#   '3º quartil': 27.0,
#   'minimo': 13,
#   'maximo': 44,
#   'media': 24.42689434364995,
#   'desvio_padrao': 4.634647740896915,
#   'variancia': 21.479959682200878,
#   'limite inferior': 12.0,
#   'limite superior': 36.0},
#  'Golf': {'mediana': 29.0,
#   '1º quartil': 23.0,
#   '3º quartil': 35.0,
#   'minimo': 15,
#   'maximo': 50,
#   'media': 29.412955465587043,
#   'desvio_padrao': 7.8626105386028415,
#   'variancia': 61.82064448174847,
#   'limite inferior': 5.0,
#   'limite superior': 53.0},
#  'Gymnastics': {'mediana': 23.0,
#   '1º quartil': 19.0,
#   '3º quartil': 25.0,
#   'minimo': 10,
#   'maximo': 49,
#   'media': 22.81401879657019,
#   'desvio_padrao': 4.821315658220146,
#   'variancia': 23.24508467619876,
#   'limite inferior': 10.0,
#   'limite superior': 34.0},
#  'Handball': {'mediana': 26.0,
#   '1º quartil': 23.0,
#   '3º quartil': 29.0,
#   'minimo': 14,
#   'maximo': 43,
#   'media': 26.310231923601638,
#   'desvio_padrao': 4.1294641816630175,
#   'variancia': 17.05247442763781,
#   'limite inferior': 14.0,
#   'limite superior': 38.0},
#  'Hockey': {'mediana': 26.0,
#   '1º quartil': 23.0,
#   '3º quartil': 28.0,
#   'minimo': 15,
#   'maximo': 44,
#   'media': 25.72752446003323,
#   'desvio_padrao': 3.9621507414031303,
#   'variancia': 15.698638497601376,
#   'limite inferior': 15.5,
#   'limite superior': 35.5},
#  'Ice Hockey': {'mediana': 25.0,
#   '1º quartil': 23.0,
#   '3º quartil': 29.0,
#   'minimo': 15,
#   'maximo': 48,
#   'media': 25.832306018854243,
#   'desvio_padrao': 4.427882541564653,
#   'variancia': 19.606143801893047,
#   'limite inferior': 14.0,
#   'limite superior': 38.0},
#  'Judo': {'mediana': 25.0,
#   '1º quartil': 23.0,
#   '3º quartil': 28.0,
#   'minimo': 14,
#   'maximo': 43,
#   'media': 25.326229939489608,
#   'desvio_padrao': 3.8993074579115254,
#   'variancia': 15.204598651324444,
#   'limite inferior': 15.5,
#   'limite superior': 35.5},
#  'Lacrosse': {'mediana': 27.0,
#   '1º quartil': 25.0,
#   '3º quartil': 27.0,
#   'minimo': 14,
#   'maximo': 37,
#   'media': 26.916666666666668,
#   'desvio_padrao': 3.8013898736845464,
#   'variancia': 14.450564971751412,
#   'limite inferior': 22.0,
#   'limite superior': 30.0},
#  'Luge': {'mediana': 24.0,
#   '1º quartil': 21.0,
#   '3º quartil': 27.0,
#   'minimo': 15,
#   'maximo': 53,
#   'media': 24.626774847870184,
#   'desvio_padrao': 4.881684010610287,
#   'variancia': 23.830838779448133,
#   'limite inferior': 12.0,
#   'limite superior': 36.0},
#  'Modern Pentathlon': {'mediana': 26.0,
#   '1º quartil': 23.0,
#   '3º quartil': 29.0,
#   'minimo': 15,
#   'maximo': 53,
#   'media': 26.376267143709004,
#   'desvio_padrao': 4.103056040769983,
#   'variancia': 16.835068873699054,
#   'limite inferior': 14.0,
#   'limite superior': 38.0},
#  'Motorboating': {'mediana': 32.0,
#   '1º quartil': 29.0,
#   '3º quartil': 35.5,
#   'minimo': 26,
#   'maximo': 54,
#   'media': 33.875,
#   'desvio_padrao': 7.693070475001079,
#   'variancia': 59.18333333333333,
#   'limite inferior': 19.25,
#   'limite superior': 45.25},
#  'Nordic Combined': {'mediana': 24.0,
#   '1º quartil': 22.0,
#   '3º quartil': 27.0,
#   'minimo': 15,
#   'maximo': 39,
#   'media': 24.340029761904763,
#   'desvio_padrao': 3.8971901593781744,
#   'variancia': 15.188091138354078,
#   'limite inferior': 14.5,
#   'limite superior': 34.5},
#  'Rhythmic Gymnastics': {'mediana': 18.0,
#   '1º quartil': 17.0,
#   '3º quartil': 20.0,
#   'minimo': 13,
#   'maximo': 30,
#   'media': 18.737082066869302,
#   'desvio_padrao': 2.505250254869902,
#   'variancia': 6.276278839525707,
#   'limite inferior': 12.5,
#   'limite superior': 24.5},
#  'Rowing': {'mediana': 25.0,
#   '1º quartil': 22.0,
#   '3º quartil': 28.0,
#   'minimo': 11,
#   'maximo': 60,
#   'media': 25.262576687116564,
#   'desvio_padrao': 4.311755093427032,
#   'variancia': 18.591231985693952,
#   'limite inferior': 13.0,
#   'limite superior': 37.0},
#  'Rugby': {'mediana': 24.0,
#   '1º quartil': 23.0,
#   '3º quartil': 25.0,
#   'minimo': 18,
#   'maximo': 39,
#   'media': 24.271604938271604,
#   'desvio_padrao': 2.942565516366986,
#   'variancia': 8.658691818112109,
#   'limite inferior': 20.0,
#   'limite superior': 28.0},
#  'Rugby Sevens': {'mediana': 26.0,
#   '1º quartil': 23.0,
#   '3º quartil': 29.0,
#   'minimo': 18,
#   'maximo': 36,
#   'media': 26.046822742474916,
#   'desvio_padrao': 3.7726250281074214,
#   'variancia': 14.232699602702523,
#   'limite inferior': 14.0,
#   'limite superior': 38.0},
#  'Sailing': {'mediana': 29.0,
#   '1º quartil': 25.0,
#   '3º quartil': 34.0,
#   'minimo': 13,
#   'maximo': 71,
#   'media': 30.319010021257213,
#   'desvio_padrao': 7.819516497871963,
#   'variancia': 61.14483826049182,
#   'limite inferior': 11.5,
#   'limite superior': 47.5},
#  'Shooting': {'mediana': 34.0,
#   '1º quartil': 27.0,
#   '3º quartil': 38.0,
#   'minimo': 15,
#   'maximo': 72,
#   'media': 33.462788259958074,
#   'desvio_padrao': 8.261886628651661,
#   'variancia': 68.25877066469312,
#   'limite inferior': 10.5,
#   'limite superior': 54.5},
#  'Short Track Speed Skating': {'mediana': 23.0,
#   '1º quartil': 20.0,
#   '3º quartil': 25.0,
#   'minimo': 13,
#   'maximo': 35,
#   'media': 22.804432855280314,
#   'desvio_padrao': 3.803501138558231,
#   'variancia': 14.46662091101376,
#   'limite inferior': 12.5,
#   'limite superior': 32.5},
#  'Skeleton': {'mediana': 29.0,
#   '1º quartil': 25.0,
#   '3º quartil': 33.0,
#   'minimo': 18,
#   'maximo': 53,
#   'media': 29.844221105527637,
#   'desvio_padrao': 6.396088946336761,
#   'variancia': 40.909953809451295,
#   'limite inferior': 13.0,
#   'limite superior': 45.0},
#  'Ski Jumping': {'mediana': 23.0,
#   '1º quartil': 20.0,
#   '3º quartil': 26.0,
#   'minimo': 14,
#   'maximo': 43,
#   'media': 23.34527280299875,
#   'desvio_padrao': 4.058774899642031,
#   'variancia': 16.47365368596418,
#   'limite inferior': 11.0,
#   'limite superior': 35.0},
#  'Snowboarding': {'mediana': 24.0,
#   '1º quartil': 21.0,
#   '3º quartil': 28.0,
#   'minimo': 14,
#   'maximo': 40,
#   'media': 24.825854700854702,
#   'desvio_padrao': 4.629435501818402,
#   'variancia': 21.431673065496597,
#   'limite inferior': 10.5,
#   'limite superior': 38.5},
#  'Softball': {'mediana': 26.0,
#   '1º quartil': 23.0,
#   '3º quartil': 29.0,
#   'minimo': 17,
#   'maximo': 41,
#   'media': 26.299163179916317,
#   'desvio_padrao': 4.298168803509611,
#   'variancia': 18.474255063463243,
#   'limite inferior': 14.0,
#   'limite superior': 38.0},
#  'Speed Skating': {'mediana': 24.0,
#   '1º quartil': 21.0,
#   '3º quartil': 27.0,
#   'minimo': 13,
#   'maximo': 52,
#   'media': 24.30589702476394,
#   'desvio_padrao': 4.254044547510343,
#   'variancia': 18.09689501220248,
#   'limite inferior': 12.0,
#   'limite superior': 36.0},
#  'Swimming': {'mediana': 20.0,
#   '1º quartil': 18.0,
#   '3º quartil': 23.0,
#   'minimo': 11,
#   'maximo': 46,
#   'media': 20.572752748437164,
#   'desvio_padrao': 3.6963399727961286,
#   'variancia': 13.662929194490484,
#   'limite inferior': 10.5,
#   'limite superior': 30.5},
#  'Synchronized Swimming': {'mediana': 22.0,
#   '1º quartil': 20.0,
#   '3º quartil': 25.0,
#   'minimo': 15,
#   'maximo': 40,
#   'media': 22.365236523652364,
#   'desvio_padrao': 3.423606419941485,
#   'variancia': 11.721080918664551,
#   'limite inferior': 12.5,
#   'limite superior': 32.5},
#  'Table Tennis': {'mediana': 26.0,
#   '1º quartil': 22.0,
#   '3º quartil': 30.0,
#   'minimo': 15,
#   'maximo': 54,
#   'media': 26.462404092071612,
#   'desvio_padrao': 5.677353001511387,
#   'variancia': 32.23233710377035,
#   'limite inferior': 10.0,
#   'limite superior': 42.0},
#  'Taekwondo': {'mediana': 24.0,
#   '1º quartil': 21.0,
#   '3º quartil': 27.0,
#   'minimo': 16,
#   'maximo': 37,
#   'media': 24.056105610561055,
#   'desvio_padrao': 4.061529331562438,
#   'variancia': 16.496020511142028,
#   'limite inferior': 12.0,
#   'limite superior': 36.0},
#  'Tennis': {'mediana': 25.0,
#   '1º quartil': 22.0,
#   '3º quartil': 29.0,
#   'minimo': 13,
#   'maximo': 47,
#   'media': 25.88085255066387,
#   'desvio_padrao': 4.995571989631606,
#   'variancia': 24.955739503591882,
#   'limite inferior': 11.5,
#   'limite superior': 39.5},
#  'Trampolining': {'mediana': 24.5,
#   '1º quartil': 22.0,
#   '3º quartil': 28.0,
#   'minimo': 18,
#   'maximo': 39,
#   'media': 25.138157894736842,
#   'desvio_padrao': 4.484039897538683,
#   'variancia': 20.10661380271872,
#   'limite inferior': 13.0,
#   'limite superior': 37.0},
#  'Triathlon': {'mediana': 28.0,
#   '1º quartil': 25.0,
#   '3º quartil': 31.0,
#   'minimo': 18,
#   'maximo': 42,
#   'media': 27.871455576559548,
#   'desvio_padrao': 4.218748508239028,
#   'variancia': 17.79783897576903,
#   'limite inferior': 16.0,
#   'limite superior': 40.0},
#  'Tug-Of-War': {'mediana': 29.0,
#   '1º quartil': 26.0,
#   '3º quartil': 32.0,
#   'minimo': 17,
#   'maximo': 45,
#   'media': 29.229411764705883,
#   'desvio_padrao': 5.283698801475424,
#   'variancia': 27.917473024712834,
#   'limite inferior': 17.0,
#   'limite superior': 41.0},
#  'Volleyball': {'mediana': 25.0,
#   '1º quartil': 22.0,
#   '3º quartil': 28.0,
#   'minimo': 15,
#   'maximo': 41,
#   'media': 25.185957696827263,
#   'desvio_padrao': 4.033334826915429,
#   'variancia': 16.267789826008915,
#   'limite inferior': 13.0,
#   'limite superior': 37.0},
#  'Water Polo': {'mediana': 26.0,
#   '1º quartil': 23.0,
#   '3º quartil': 28.0,
#   'minimo': 14,
#   'maximo': 45,
#   'media': 25.677327093083722,
#   'desvio_padrao': 4.297292912726305,
#   'variancia': 18.466726377767728,
#   'limite inferior': 15.5,
#   'limite superior': 35.5},
#  'Weightlifting': {'mediana': 25.0,
#   '1º quartil': 23.0,
#   '3º quartil': 28.0,
#   'minimo': 15,
#   'maximo': 45,
#   'media': 25.528067056134113,
#   'desvio_padrao': 4.239859632442966,
#   'variancia': 17.976409702819403,
#   'limite inferior': 15.5,
#   'limite superior': 35.5},
#  'Wrestling': {'mediana': 26.0,
#   '1º quartil': 23.0,
#   '3º quartil': 28.0,
#   'minimo': 15,
#   'maximo': 50,
#   'media': 25.812133072407043,
#   'desvio_padrao': 3.9877049058967065,
#   'variancia': 15.901790416512661,
#   'limite inferior': 15.5,
#   'limite superior': 35.5}}

# %%
df_estatisticas = pd.DataFrame.from_dict(estatisticas, orient='index')
df_estatisticas
# Out:
#                            mediana  1º quartil  3º quartil  minimo  maximo  \
# Alpine Skiing                 23.0       20.00        25.0      14      55
# Archery                       26.0       22.00        32.0      14      71
# Art Competitions              46.0       39.00        53.0      14      97
# Athletics                     25.0       22.00        28.0      12      52
# Badminton                     25.0       23.00        28.0      16      44
# Baseball                      26.0       23.00        29.0      16      44
# Basketball                    25.0       22.75        28.0      16      40
# Beach Volleyball              29.0       26.00        32.0      18      41
# Biathlon                      26.0       23.00        29.0      17      45
# Bobsleigh                     28.0       25.00        32.0      15      54
# Boxing                        23.0       21.00        25.0      15      41
# Canoeing                      25.0       22.00        28.0      15      48
# Cross Country Skiing          26.0       23.00        29.0      15      49
# Curling                       30.0       26.00        36.0      17      58
# Cycling                       24.0       22.00        27.0      14      49
# Diving                        22.0       19.00        25.0      12      51
# Equestrianism                 34.0       28.00        40.0      16      72
# Fencing                       28.0       24.00        32.0      14      63
# Figure Skating                22.0       19.00        25.0      11      52
# Football                      23.0       21.00        26.0      15      40
# Freestyle Skiing              24.0       21.00        27.0      13      44
# Golf                          29.0       23.00        35.0      15      50
# Gymnastics                    23.0       19.00        25.0      10      49
# Handball                      26.0       23.00        29.0      14      43
# Hockey                        26.0       23.00        28.0      15      44
# Ice Hockey                    25.0       23.00        29.0      15      48
# Judo                          25.0       23.00        28.0      14      43
# Lacrosse                      27.0       25.00        27.0      14      37
# Luge                          24.0       21.00        27.0      15      53
# Modern Pentathlon             26.0       23.00        29.0      15      53
# Motorboating                  32.0       29.00        35.5      26      54
# Nordic Combined               24.0       22.00        27.0      15      39
# Rhythmic Gymnastics           18.0       17.00        20.0      13      30
# Rowing                        25.0       22.00        28.0      11      60
# Rugby                         24.0       23.00        25.0      18      39
# Rugby Sevens                  26.0       23.00        29.0      18      36
# Sailing                       29.0       25.00        34.0      13      71
# Shooting                      34.0       27.00        38.0      15      72
# Short Track Speed Skating     23.0       20.00        25.0      13      35
# Skeleton                      29.0       25.00        33.0      18      53
# Ski Jumping                   23.0       20.00        26.0      14      43
# Snowboarding                  24.0       21.00        28.0      14      40
# Softball                      26.0       23.00        29.0      17      41
# Speed Skating                 24.0       21.00        27.0      13      52
# Swimming                      20.0       18.00        23.0      11      46
# Synchronized Swimming         22.0       20.00        25.0      15      40
# Table Tennis                  26.0       22.00        30.0      15      54
# Taekwondo                     24.0       21.00        27.0      16      37
# Tennis                        25.0       22.00        29.0      13      47
# Trampolining                  24.5       22.00        28.0      18      39
# Triathlon                     28.0       25.00        31.0      18      42
# Tug-Of-War                    29.0       26.00        32.0      17      45
# Volleyball                    25.0       22.00        28.0      15      41
# Water Polo                    26.0       23.00        28.0      14      45
# Weightlifting                 25.0       23.00        28.0      15      45
# Wrestling                     26.0       23.00        28.0      15      50
#
#                                media  desvio_padrao   variancia  \
# Alpine Skiing              23.212482       3.970915   15.768168
# Archery                    27.958869       8.730033   76.213481
# Art Competitions           46.054358      11.590197  134.332669
# Athletics                  25.156561       4.334278   18.785964
# Badminton                  25.671242       3.907369   15.267531
# Baseball                   26.240492       4.559829   20.792043
# Basketball                 25.311287       3.801365   14.450378
# Beach Volleyball           29.122340       4.225558   17.855344
# Biathlon                   26.533006       4.288977   18.395323
# Bobsleigh                  29.107587       5.373264   28.871967
# Boxing                     23.051927       3.350703   11.227207
# Canoeing                   25.506887       4.530367   20.524223
# Cross Country Skiing       26.006132       4.290375   18.407321
# Curling                    31.412527       7.259597   52.701747
# Cycling                    24.725665       4.291374   18.415892
# Diving                     22.495778       4.304433   18.528141
# Equestrianism              34.378941       8.298744   68.869151
# Fencing                    28.561993       6.318030   39.917505
# Figure Skating             22.238903       4.965613   24.657310
# Football                   23.710304       3.454670   11.934747
# Freestyle Skiing           24.426894       4.634648   21.479960
# Golf                       29.412955       7.862611   61.820644
# Gymnastics                 22.814019       4.821316   23.245085
# Handball                   26.310232       4.129464   17.052474
# Hockey                     25.727524       3.962151   15.698638
# Ice Hockey                 25.832306       4.427883   19.606144
# Judo                       25.326230       3.899307   15.204599
# Lacrosse                   26.916667       3.801390   14.450565
# Luge                       24.626775       4.881684   23.830839
# Modern Pentathlon          26.376267       4.103056   16.835069
# Motorboating               33.875000       7.693070   59.183333
# Nordic Combined            24.340030       3.897190   15.188091
# Rhythmic Gymnastics        18.737082       2.505250    6.276279
# Rowing                     25.262577       4.311755   18.591232
# Rugby                      24.271605       2.942566    8.658692
# Rugby Sevens               26.046823       3.772625   14.232700
# Sailing                    30.319010       7.819516   61.144838
# Shooting                   33.462788       8.261887   68.258771
# Short Track Speed Skating  22.804433       3.803501   14.466621
# Skeleton                   29.844221       6.396089   40.909954
# Ski Jumping                23.345273       4.058775   16.473654
# Snowboarding               24.825855       4.629436   21.431673
# Softball                   26.299163       4.298169   18.474255
# Speed Skating              24.305897       4.254045   18.096895
# Swimming                   20.572753       3.696340   13.662929
# Synchronized Swimming      22.365237       3.423606   11.721081
# Table Tennis               26.462404       5.677353   32.232337
# Taekwondo                  24.056106       4.061529   16.496021
# Tennis                     25.880853       4.995572   24.955740
# Trampolining               25.138158       4.484040   20.106614
# Triathlon                  27.871456       4.218749   17.797839
# Tug-Of-War                 29.229412       5.283699   27.917473
# Volleyball                 25.185958       4.033335   16.267790
# Water Polo                 25.677327       4.297293   18.466726
# Weightlifting              25.528067       4.239860   17.976410
# Wrestling                  25.812133       3.987705   15.901790
#
#                            limite inferior  limite superior
# Alpine Skiing                       12.500           32.500
# Archery                              7.000           47.000
# Art Competitions                    18.000           74.000
# Athletics                           13.000           37.000
# Badminton                           15.500           35.500
# Baseball                            14.000           38.000
# Basketball                          14.875           35.875
# Beach Volleyball                    17.000           41.000
# Biathlon                            14.000           38.000
# Bobsleigh                           14.500           42.500
# Boxing                              15.000           31.000
# Canoeing                            13.000           37.000
# Cross Country Skiing                14.000           38.000
# Curling                             11.000           51.000
# Cycling                             14.500           34.500
# Diving                              10.000           34.000
# Equestrianism                       10.000           58.000
# Fencing                             12.000           44.000
# Figure Skating                      10.000           34.000
# Football                            13.500           33.500
# Freestyle Skiing                    12.000           36.000
# Golf                                 5.000           53.000
# Gymnastics                          10.000           34.000
# Handball                            14.000           38.000
# Hockey                              15.500           35.500
# Ice Hockey                          14.000           38.000
# Judo                                15.500           35.500
# Lacrosse                            22.000           30.000
# Luge                                12.000           36.000
# Modern Pentathlon                   14.000           38.000
# Motorboating                        19.250           45.250
# Nordic Combined                     14.500           34.500
# Rhythmic Gymnastics                 12.500           24.500
# Rowing                              13.000           37.000
# Rugby                               20.000           28.000
# Rugby Sevens                        14.000           38.000
# Sailing                             11.500           47.500
# Shooting                            10.500           54.500
# Short Track Speed Skating           12.500           32.500
# Skeleton                            13.000           45.000
# Ski Jumping                         11.000           35.000
# Snowboarding                        10.500           38.500
# Softball                            14.000           38.000
# Speed Skating                       12.000           36.000
# Swimming                            10.500           30.500
# Synchronized Swimming               12.500           32.500
# Table Tennis                        10.000           42.000
# Taekwondo                           12.000           36.000
# Tennis                              11.500           39.500
# Trampolining                        13.000           37.000
# Triathlon                           16.000           40.000
# Tug-Of-War                          17.000           41.000
# Volleyball                          13.000           37.000
# Water Polo                          15.500           35.500
# Weightlifting                       15.500           35.500
# Wrestling                           15.500           35.500
